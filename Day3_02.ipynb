# %% [markdown]
# <a href="https://colab.research.google.com/github/isa015/StoveLeague/blob/master/Day3_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #5.사례를 통한 채권시장 분석

# %% [markdown]
# ###5.1 제로 금리 일본의 채권 금리가 가장 높다 : Covered Interest Rate (1)

# %% [markdown]
# * 국가간 금리 수준 비교는, 환율 변동 위험 제거 기준 으로
#
# * 자국 통화 기준으로 미국 금리가 가장 높지만, USD 기준으로는 반대 : 일본, 한국, 독일, 미국
#
# * 외국인 투자자들이 KRW 채권을 매수하는 이유 중 하나
#
# * 독일 Bund 금리가 미국 UST 금리와 괴리되는 흐름
#
# * 낮아진 US IG 스프레드까지 감안하면, US 채권의 투자 메리트는 감소하고 있음

# %% [markdown]
# > [각국의 금리 비교 (2년물 국채) : Forward 1년 가정]
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# [각국의 금리 비교 (10년물 국채) : Forward 1년 가정]
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# > [각국의 USD 환산 국채 10년물 금리]
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###5.2 독일 Bund DLS 사례 : Covered Interest Rate (2)
# * Bund 10년 금리가 (-0.3%) 아래로 내려가지 않으면 수익이 발생하는 pay off
# * 당시 Covered 기준의 독일 채권금리가 높아서 국내 기관 투자자들은 독일채권을 매수하고 있었음

# %% [markdown]
# > [독일 금리연계 DLS 사례]
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###5.3 위험한 나라들의 수익률 곡선 : 수익률 곡선에 대한 다른 해석
#
# * 그리스 위기 / 아르헨티나 위기 당시 수익률 곡선의 특징
#
#   * 높은 금리, 장단기 금리 역전
#
# * 가격으로 전환해 본다면 ?

# %% [markdown]
# ###5.4 LTCM 청산
#
# * 1994년 출범한 채권 헤지펀드 : Long Term Capital Management
#
# * **채권 Long-Short 전략 & 레버리지(Leverage)**
#
# * 1995년 총자산 수익률 2.45% --> 순자산 수익률 42.8%
#
# * 1998년 러시아 모라토리엄 계기로 청산되었으나 정작 러시아 관련 자산은 없었음
#
# * 변동성에 취약한 Short Gamma 속성
#
#   * 아시아 위기, 러시아 모라토리엄
#
#   * 스프레드 확대, 자산간 Correlation 변경

# %% [markdown]
# ### 5.5 트럼프 Liberation Day (2025년 4월 2일)
#
#   * Miran 보고서
#
#     * 경상수지 적자 축소, 달러화 약세 지향하면서 기축통화 지위 유지
#
#   * 트럼프 Liberation Day
#
#     * 10% 기본 관세 / 대미 무역 흑자국 추가 관세(중국 34%, 유럽 20%, 일본 24%, 한국 25%) / 자동차 및 자동차 부품 25% 관세
#
#   * **USD 채권 시장 : 채권-스왑, 국채-크레딧 스프레드 확대**
#
#   * **USD-UST 간 Correlation 변경**
#
#   * KRW-KOSPI 간 Correlation 변경

# %% [markdown]
# > [트럼프 정부 출범 이후, 원화 가치, KOSPI, 채권가격(10년)간 상관계수 변화 ]
#
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.6 레고랜드 사태의 교훈 : 크레딧 스프레드 변동 요인
#
# * 2022년 9월 29일. 강원도의 지급보증이행 거부로 크레딧 채권 거래 중단.
#
# * PF에 대한 우려 있었으나 문제가 현실화된 발행사는 없었음
#
# * 한국은행의 급격한 기준금리 인상 : 1 % --> 3.25% (10월~12월 : 0.75)
#
#   * 이미 2Q 부터 여전채 중심으로 크레딧 채권의 거래 유동성 저하가 진행
#
# * 급격한 평가손을 겪은 증권사 신탁의 환매 중단으로 크레딧 거래 유동성 급감
#
# * 전기요금 인상이 막힌 한국전력의 급격한 채권 발행 증가 --> 공사채 약세

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.5 영국 연기금과 한국 보험사들의 2021년 유동성 부족 : 환율과 채권
#
# * 2021년 9월 22일 영국의 감세법안 발표
#
#    * 향후 18개월 국채 조달 금액 = 지난 54개월간 국채 조달 금액
#    * Gilt 10년 금리 : 3일간 +93 bp
#    * USD 대비 GBP : 1.38 (8월말)--> 1.03 (9월 최저점): 25% 하락
#
# * USD 강세로 인해, **GBP와 KRW는 이전부터 약세 압력**에 노출 되어 있었음
#
# * 보험사들의 유동성 경색
#
#  * 통화 약세 --> 해외로 투자된 자산에 대한 환헤지 롤 오버시 유동성 필요
#  * 채권 약세 --> 평가손 발생 --> 손실 실현 없는 유동성 마련 방안 차단
#
# * 은행과 달리 보험사는 차입 금지 : 긴급 조치로 보험사의 Repo 매도 허용
#
# * 한국 보험사의 경우, 저축성 보험의 대규모 만기 도래에 따른 개별적인 유동성 경색요인도 있었으나,
#
# * 환헤지가 병행되는 해외 투자는 자국 통화 약세시 해당 기관의 유동성을 급격히 약화시키는 요인으로 작용할 수 있음을 상기시켜 줌
#
# * 은행의 경우, 원화 약세시 외화 자산의 가치 상승으로 인한 RWA 상승 이슈로 배당가능 여력 약화

# %% [markdown]
# ## 5.7 보험사 부채시가평가, KICS 와 KRW 장기채권 금리
#
#  * 보험사의 부채 : KRW 장기 부채
#
#    * 부채 듀레이션 증가
#
#      * 기대수명 증가
#      * 채권금리 하락
#
# * 부채시가평가, KICS 등으로 보험사에 대한 규제 체계 강화로 KRW 채권에 집중
#
#  * 해외 금리 자산은 국내 금리 체계와의 연동성이 상대적으로 작음
#
# * KRW 중심의 자산 듀레이션 확대 : 듀레이션을 산다
#
# * 대응 수단
#
#     * 만기 30년 이상의 국채 : 10년-30년 국채 금리 역전의 원인
#     * STRIP 채권의 원금(Principal)
#     * KRW Bond Forward : 현금 없이 채권 확보

# %% [markdown]
# ## 5.8 최근 6개월과 가장 유사한 기간은 언제인가 : 주성분 분석의 쓸모
#
# * 주성분 분석의 쓸모 : 유사 기간 탐색기
#
# * 유사 기간 : 2010-11-10 ~ 2011-05-11
#
# * 22개 변수 : 유가, 구리, 금 / 유로, 엔, 원, 위안, 호주 달러, 브라질 헤알, 달러 인덱스 / KOSPI, S&P, STOXX, 니케이, CSI / TED, VIX, 이머징 크레딧 스프레드 / UST 10년 채권 가격, Bund 10년 채권 가격, KTB 10년 채권 가격 / 미국 물가채 스프레드
#
# * 해당 기간 글로벌 이벤트
#
#  * 유럽 재정 위기 심화 : 유럽 국가들의 부채 문제 지속
#  * 미국 연준의 양적 완화 정책(QE2) 발표 : 2010년 11월
#  * 일본 대지진과 원전 사고 : 2011년 3월 11일. 글로벌 공급망에 영향.
#
#
#
#  * 미국 신용등급 강등은 이후 기간에 발생(2011년 8월 5일)

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# > ![image.png](data:image/png;base64,...)
